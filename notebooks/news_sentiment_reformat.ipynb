# %%
# %cd ..

# %%
import os, xml, json, spacy
import xml.etree.ElementTree as ET
import pandas as pd
from tqdm import tqdm

# %%
nlp = spacy.load("hr_core_news_lg")

# %% [markdown]
# ## STONE

# %%
stone = pd.read_csv("data/stone/stone_3k.csv")[['document_id', 'text', 'aggregated_tone']]

tone_dict = {"Ton - NEG": 0,
             "Ton - NEUTR": 1,
             "Ton - POZ": 2}

stone['label'] = stone['aggregated_tone'].map(tone_dict)
stone = stone.drop(columns=['aggregated_tone'])
stone

# %%
stone['label'].value_counts()

# %%
import re

class Lemmatizer():
    def __init__(self):
        self.lemmas = {}
        # __init__ should ensure the file is downloaded on import
        self.pattern = re.compile("\w+")
        with open("data/molex/molex14_word2lemma.txt") as fin:
            for line in fin:
                word, lemma = line.split()
                self.lemmas[word] = lemma

    def lemmatize_word(self, word):
        lemma = self.lemmas.get(word.lower())
        if lemma:
            return lemma
        else:
            return word[:5]

    def lemmatize_string(self, string):
        lemmas = []
        for token in re.findall(self.pattern, string.lower()):
            lemmas.append(self.lemmatize_word(token))
        return " ".join(lemmas)
# Out:
# <>:7: SyntaxWarning: invalid escape sequence '\w'
# <>:7: SyntaxWarning: invalid escape sequence '\w'
# /tmp/ipykernel_217631/943492292.py:7: SyntaxWarning: invalid escape sequence '\w'
#   self.pattern = re.compile("\w+")

# %%
def parse_word(tagged_word):
    word = tagged_word.find('Word').text
    tag = tagged_word.find('POSTag').text
    lemma = tagged_word.find('Lemma').text
    stem = tagged_word.find('BasicStem').text

    return word, tag, lemma, stem

# %%
molex = Lemmatizer()

# %%
import string

all_tags = set()
raw_documents = {}

pos_tag_words = {}

for idx, row in tqdm(stone.iterrows(), total=len(stone)):

    doc = nlp(row['text'])
    doc_tokens = []
    
    for token in doc:
        word = token.text
        pos = token.pos_.lower()
        lemma = molex.lemmatize_word(word.lower()) 
        # lemmatize
        doc_tokens.append((lemma, pos))
    
    doc_tokens = [(word, pos) for word, pos in doc_tokens if word not in string.punctuation]
        
    raw_documents[idx] = {
        'text':doc_tokens,
        'label': row['label'],
        'docid': idx,
    }
# Out:
# 100%|██████████| 2880/2880 [00:12<00:00, 235.70it/s]

# %%
raw_documents

# %%
out_name = 'data/stone/stone_clean_tokens.jsonl'

with open(out_name, 'w') as outfile:
    for k, instance in raw_documents.items():
        outfile.write(json.dumps(instance)+"\n")

# %% [markdown]
# ## 24sata

# %%
news = pd.read_csv('/shared/lovorka/internal/retriever/data/retriever_24sata_diachronic_sentiment_dump.csv')
news_sentiment_labels = pd.read_csv('data/24sata_sentiment.tsv', sep='\t')

# %%
def transform_url(url):
    url_id = url.split('-')[-1]
    url_domain = url.split('.hr/')[0]  + '.hr/'
    return url_domain + '--' + url_id
    

news['url'] = news['url'].str.replace('https', 'http', regex=False)
news['transformed_url'] = news['url'].apply(transform_url)
news[['url', 'transformed_url']]
# Out:
#                                                      url  \
# 0      http://24sata.hr/news/inovatori-iz-zagreba-uz-...
# 1      http://24sata.hr/news/uciteljica-skidala-tange...
# 2      http://24sata.hr/news/protiv-najezde-krvopija-...
# 3      http://joomboos.24sata.hr/bez-srama/snimila-se...
# 4      http://joomboos.24sata.hr/bez-srama/sve-je-pre...
# ...                                                  ...
# 22474  http://24sata.hr/show/najslabija-karika-tko-se...
# 22475  http://joomboos.24sata.hr/bez-srama/pametnjako...
# 22476  http://24sata.hr/show/osim-oca-pravnu-kontrolu...
# 22477  http://joomboos.24sata.hr/bez-srama/prvi-tampo...
# 22478  http://www.24sata.hr/news/odvjetnik-obitelji-z...
#
#                          transformed_url
# 0              http://24sata.hr/--796736
# 1              http://24sata.hr/--887394
# 2              http://24sata.hr/--911295
# 3      http://joomboos.24sata.hr/--11435
# 4      http://joomboos.24sata.hr/--10801
# ...                                  ...
# 22474          http://24sata.hr/--173140
# 22475   http://joomboos.24sata.hr/--5705
# 22476          http://24sata.hr/--261169
# 22477   http://joomboos.24sata.hr/--7452
# 22478     http://www.24sata.hr/--1012986
#
# [22479 rows x 2 columns]

# %%
news_merged = pd.merge(news, news_sentiment_labels, left_on='transformed_url', right_on='url', how='inner')
news_merged['article'] = news_merged['title'] + ' ' + news_merged['body']
news_merged
# Out:
#                                                   url_x  \
# 0     http://joomboos.24sata.hr/bez-srama/sve-je-pre...
# 1     http://joomboos.24sata.hr/prvi/beyonce-sa-7-go...
# 2     http://joomboos.24sata.hr/bez-srama/ovaj-tip-s...
# 3     http://joomboos.24sata.hr/prvi/4-ideje-za-zims...
# 4     http://joomboos.24sata.hr/prvi/doris-slavi-okr...
# ...                                                 ...
# 1757  http://gastro.24sata.hr/spajza/posao-iz-snova-...
# 1758  http://gastro.24sata.hr/spajza/punjena-pileca-...
# 1759  http://gastro.24sata.hr/spajza/stizu-jagode-ov...
# 1760  http://joomboos.24sata.hr/bez-srama/ciro-uskor...
# 1761  http://joomboos.24sata.hr/bez-srama/mama-uzasn...
#
#                                                   title  \
# 0     Sve je prevarila: Pogledajte što radi na Insta...
# 1            Beyonce sa 7 godina: Blue Ivy je ista mama
# 2     Ovaj tip se fotošopira na sve fotke Kendall Je...
# 3               4 ideje za zimski dejt ako si lijenčina
# 4     Doris slavi okrugli broj pratitelja na Instagr...
# ...                                                 ...
# 1757  Posao iz snova? Bistro iz Đakova traži degusta...
# 1758     Punjena pileća prsa na četiri genijalna načina
# 1759              Top 5 recepata za slastice s jagodama
# 1760  Uskoro slavi 84. rođendan: Ovo su Ćirine najbo...
# 1761  'Mama, užasna si': Mali George uvrijedio Kate ...
#
#                                                    body       date_published  \
# 0     Ona je savršen primjer koliko je edit genijaln...  2019-01-31 00:00:00
# 1     Beyonce je usporedila fotku sebe kada je imala...  2019-01-26 00:00:00
# 2     Ovaj frajer osvaja internet svojim urnebesnim ...  2019-01-24 00:00:00
# 3     Dok tvoji frendovi maštaju o savršenom dejtu n...  2018-12-26 00:00:00
# 4     Doris je tek nedavno pobijedila na Videostaru,...  2019-04-30 00:00:00
# ...                                                 ...                  ...
# 1757  Posao koji u bistro i pizzerija Loora nudi jes...  2019-01-28 00:00:00
# 1758  Pileća prsa, rekli bi znalci, sama po sebi pop...  2019-02-21 00:00:00
# 1759  Izabrali smo 5 recepata naših kolumnista u koj...  2024-04-27 00:00:00
# 1760  Legenda hrvatskog nogometa i trener svih trene...  2019-02-10 00:00:00
# 1761  Navodno joj je to rekao tijekom nogometne utak...  2019-03-04 00:00:00
#
#                         transformed_url    ID  \
# 0     http://joomboos.24sata.hr/--10801   985
# 1     http://joomboos.24sata.hr/--10741  1728
# 2     http://joomboos.24sata.hr/--10727  1570
# 3     http://joomboos.24sata.hr/--10327  1788
# 4     http://joomboos.24sata.hr/--11973  1850
# ...                                 ...   ...
# 1757    http://gastro.24sata.hr/--22977  1841
# 1758    http://gastro.24sata.hr/--23132   880
# 1759    http://gastro.24sata.hr/--23481  1988
# 1760  http://joomboos.24sata.hr/--10926   737
# 1761  http://joomboos.24sata.hr/--11202   869
#
#                                   url_y     label  \
# 0     http://joomboos.24sata.hr/--10801   neutral
# 1     http://joomboos.24sata.hr/--10741   neutral
# 2     http://joomboos.24sata.hr/--10727   neutral
# 3     http://joomboos.24sata.hr/--10327   neutral
# 4     http://joomboos.24sata.hr/--11973  positive
# ...                                 ...       ...
# 1757    http://gastro.24sata.hr/--22977  positive
# 1758    http://gastro.24sata.hr/--23132  positive
# 1759    http://gastro.24sata.hr/--23481  positive
# 1760  http://joomboos.24sata.hr/--10926  positive
# 1761  http://joomboos.24sata.hr/--11202   neutral
#
#                                                 article
# 0     Sve je prevarila: Pogledajte što radi na Insta...
# 1     Beyonce sa 7 godina: Blue Ivy je ista mama Bey...
# 2     Ovaj tip se fotošopira na sve fotke Kendall Je...
# 3     4 ideje za zimski dejt ako si lijenčina Dok tv...
# 4     Doris slavi okrugli broj pratitelja na Instagr...
# ...                                                 ...
# 1757  Posao iz snova? Bistro iz Đakova traži degusta...
# 1758  Punjena pileća prsa na četiri genijalna načina...
# 1759  Top 5 recepata za slastice s jagodama Izabrali...
# 1760  Uskoro slavi 84. rođendan: Ovo su Ćirine najbo...
# 1761  'Mama, užasna si': Mali George uvrijedio Kate ...
#
# [1762 rows x 9 columns]

# %%
def remove_string_from_column(df, column_name, string_to_remove):
    """
    Removes a specific string from a specified column in a DataFrame if it exists.

    Parameters:
    df (pd.DataFrame): The DataFrame to modify.
    column_name (str): The name of the column to process.
    string_to_remove (str): The string to remove from the column.

    Returns:
    pd.DataFrame: The modified DataFrame.
    """
    df[column_name] = df[column_name].str.replace(string_to_remove, "", regex=False)
    return df

# %%
tone_dict = {"negative": 0,
             "neutral": 1,
             "positive": 2}

news_merged['label'] = news_merged['label'].map(tone_dict)
news_merged['label'].value_counts()
# Out:
# label
# 1    1103
# 0     386
# 2     273
# Name: count, dtype: int64

# %%
string_to_remove = "Igre na sreću mogu izazvati ovisnost. 18+"
news_merged = remove_string_from_column(news_merged, 'article', string_to_remove)

# %%
news_merged.to_csv('data/24sata/24sata_date.csv', index=False)

# %%
# Determine the minimum count among the labels
min_count = news_merged['label'].value_counts().min()

# Sample an equal number of rows for each label
balanced_sample = news_merged.groupby('label').apply(lambda x: x.sample(min_count)).reset_index(drop=True)

balanced_sample['label'].value_counts()
# Out:
# /tmp/ipykernel_217631/645284274.py:5: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   balanced_sample = news_merged.groupby('label').apply(lambda x: x.sample(min_count)).reset_index(drop=True)
# label
# 0    273
# 1    273
# 2    273
# Name: count, dtype: int64

# %%
import string

all_tags = set()
raw_documents = {}

pos_tag_words = {}

for idx, row in tqdm(balanced_sample.iterrows(), total=len(balanced_sample)):

    doc = nlp(row['article'])
    doc_tokens = []
    
    for token in doc:
        word = token.text
        pos = token.pos_.lower()
        lemma = molex.lemmatize_word(word.lower()) 
        # lemmatize
        doc_tokens.append((lemma, pos))
    
    doc_tokens = [(word, pos) for word, pos in doc_tokens if word not in string.punctuation]
        
    raw_documents[idx] = {
        'text':doc_tokens,
        'label': row['label'],
        'docid': idx,
    }
# Out:
# 100%|██████████| 819/819 [00:19<00:00, 41.82it/s]

# %%
out_name = 'data/24sata/24sata_clean_tokens.jsonl'

with open(out_name, 'w') as outfile:
    for k, instance in raw_documents.items():
        outfile.write(json.dumps(instance)+"\n")
